# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
#Load Data Set
df = pd.read_csv(r"C:\Users\mggon\Documents\Repositories\HW\homework\Data_Plant_New.csv")

# %%
df.head(10)
# Out:
#       39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 0  39527.25208    27.471821    27.566410     8.869142     5.396484
# 1  39527.25417    27.477289    27.539061     8.734374     5.404296
# 2  39527.25625    27.482759          NaN     8.734374     5.427734
# 3  39527.25833    27.488220    27.476561     8.756347     5.427734
# 4  39527.26042    27.493690    27.468750     8.756347     5.427734
# 5  39527.26250    27.499161    27.737310     8.822266     5.427734
# 6  39527.26458    27.503080    28.640631     9.648439     5.488281
# 7  39527.26667    27.496700    28.394529     9.537109     5.457031
# 8  39527.26875    27.490320    28.534180     9.191404     5.548828
# 9  39527.27083    27.483950    28.394529     9.466796     5.526855
#
#    1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# 0  1698.780029     7.370453    78.717918     13.69824  36.843750  ...
# 1  1703.457031     7.374215    78.399452     13.74219  36.843750  ...
# ...

# %%
df.describe()
# Out:
#            39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# count   7199.000000  7198.000000  7198.000000  7199.000000  7199.000000
# mean   39534.750000    27.127295    27.953209     9.593198     6.395699
# std        4.329826     0.674680     0.698533     0.630545     0.952640
# min    39527.252080    24.231501    24.593750     7.673828     4.951172
# 25%    39531.001040    26.652867    27.507811     9.191404     5.640625
# 50%    39534.750000    27.109890    27.906250     9.570802     6.177734
# 75%    39538.498960    27.518567    28.394529     9.923826     6.958984
# max    39542.247920    47.017712    42.443359    17.277340    19.515141
#
#        1691.651001  7.366691113  78.55264282  13.51465034     36.84375  ...  \
# count  7199.000000  7199.000000  7199.000000  7199.000000  7199.000000  ...
# mean   1701.915367    11.555007    76.332696    18.356032    37.815861  ...
# std      99.738546     2.901431     3.595688     3.648891     1.768092  ...
# ...

# %%
df.shape
# Out:
# (7199, 27)

# %%
df.columns = df.columns.str.upper()

# %% [markdown]
# 2.	Check for missing values in the dataset. Use the attribute mean to fill in the missing value.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(11)

# %%
df_mean = df.fillna(df.mean())

# %%
df_drop_dup = df.drop_duplicates()

# %% [markdown]
# 3.	Split the preprocessed data for training, validation and testing. The data should be split will be 70% training, 15% validation and the testing will be 15%. Show the length of each split.

# %%
x_train, x_test = train_test_split(df, test_size = 0.7, random_state=42)
x_train2, x_val = train_test_split(x_train, test_size = 0.16, random_state=42)

# %%
print(len(x_train2))
print(len(x_test))
print(len(x_val))
# Out:
# 1813
# 5040
# 346

# %% [markdown]
# 4.	Using any transformation methods, normalize/standardize all numerical features.

# %%
x_train2.head()
# Out:
#          39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 5511  39538.73333    27.374201    28.027340    10.064450     6.515625
# 3430  39534.39792    26.901360    27.539061     9.373048     5.472656
# 6870  39541.56458    27.722469    27.843750     9.518359     6.759766
# 5772  39539.27708    26.046940    26.894529     8.916018     5.978516
# 3642  39534.83958    27.814671    28.546881     9.835939     7.341797
#
#       1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# 5511  1709.961060    12.526370    76.970734    20.618759  37.400391  ...
# 3430  1765.428955     9.276216    77.721786    15.550780  36.984379  ...
# 6870  1762.900024    13.478130    73.442673    20.578131  38.455078  ...
# 5772  1704.150024    10.960760    79.528038    18.433590  37.031250  ...
# 3642  1646.240967    14.110910    72.263557    22.234381  37.998051  ...
#
#       3.066406012  55.95146179  71.27528381  30.65937042  30.5925808  \
# ...

# %%
x_val.head()
# Out:
#          39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 3073  39533.65417    27.410160    27.691410     9.191404     8.526172
# 454   39528.19792    27.160400    28.148439     9.242675     5.427734
# 1500  39530.37708    26.538280    27.722660     9.285156     5.365234
# 66    39527.38958    27.120440    27.812500     9.075684     5.548828
# 5490  39538.68958    27.309601    27.812500    10.339850     6.806640
#
#       1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# 3073  1826.758057    16.866159    71.906403    22.816410  37.810551  ...
# 454   1693.691040     7.486065    83.224167    11.628910  36.802731  ...
# 1500  1691.766968     7.677331    79.850639    11.015630  36.708981  ...
# 66    1746.055054     8.559603    78.427979    12.855470  37.031250  ...
# 5490  1707.177979    12.956400    77.008148    21.200781  37.582031  ...
#
#       3.066406012  55.95146179  71.27528381  30.65937042  30.5925808  \
# ...

# %%
x_test
# Out:
#          39527.25  27.46636009  27.62891006  8.822265625  5.396483898  \
# 4899  39537.45833    26.856621    28.335939    10.246090     6.969922
# 2531  39532.52500    26.997290    27.937500    10.568360     7.126954
# 6652  39541.11042    26.567160    27.906250     9.875488     5.595703
# 1287  39529.93333    26.568489    27.476561     9.560548     5.718750
# 2540  39532.54375    26.976641    27.903130    10.292970     6.974609
# ...           ...          ...          ...          ...          ...
# 4470  39536.56458    27.717760    27.750000     9.695311     5.427734
# 891   39529.10833    27.740589    28.609381     9.835939     5.611328
# 2793  39533.07083    26.530161    27.445311     9.238280     5.718750
# 6044  39539.84375    26.117920    26.953131     8.734374     5.947266
# 4403  39536.42500    26.271170    27.167000     8.869142     5.656250
#
#       1691.651001  7.366691113  78.55264282  13.51465034   36.84375  ...  \
# ...

# %% [markdown]
# Scaling

# %%
scaler = StandardScaler().fit(x_train2)

# %%
df_scaled = scaler.transform(x_train2)

# %%
df_scaled
# Out:
# array([[ 0.91518458,  0.40555733,  0.1133387 , ..., -0.04500672,
#         -0.05923724,  0.09562708],
#        [-0.09123003, -0.37724938, -0.63762859, ..., -0.87462536,
#         -0.2670856 ,  0.07703292],
#        [ 1.57242607,  0.98212911, -0.16902024, ...,  0.56952706,
#         -0.54212572,  0.06856199],
#        ...,
#        [-0.13233939, -0.45898298, -0.07289606, ..., -1.14433746,
#          0.3242665 ,  0.07190731],
#        [ 1.43798086, -1.24422114, -1.91126817, ...,  1.23868432,
#          0.75267508,  0.06329093],
#        [-0.85341891, -1.01787488, -0.87793905, ..., -0.47517812,
#         -0.49457978,  0.06194116]])

# %% [markdown]
# Transformation

# %%
def log_transform(x):
    return np.log(x + 1)

df_log = log_transform(df_scaled)
# Out:
# C:\Users\mggon\AppData\Local\Temp\ipykernel_24208\859287776.py:2: RuntimeWarning: invalid value encountered in log
#   return np.log(x + 1)

# %%
df_log
# Out:
# array([[ 0.649814  ,  0.3404339 ,  0.10736333, ..., -0.04605098,
#         -0.06106429,  0.09132688],
#        [-0.09566327, -0.47360914, -1.01508559, ..., -2.07644894,
#         -0.31072637,  0.07420997],
#        [ 0.94484945,  0.68417158, -0.18514984, ...,  0.45077434,
#         -0.78116062,  0.06631381],
#        ...,
#        [-0.14195465, -0.61430455, -0.07568959, ...,         nan,
#          0.28085872,  0.0694396 ],
#        [ 0.89117018,         nan,         nan, ...,  0.80588834,
#          0.56114324,  0.06136875],
#        [-1.9201765 ,         nan, -2.10323477, ..., -0.64469634,
#         -0.68236507,  0.06009852]])
